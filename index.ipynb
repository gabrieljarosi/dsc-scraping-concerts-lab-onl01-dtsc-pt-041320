# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
# Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
# Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time

# %%
html_page = requests.get('https://www.residentadvisor.net/events/us/newyork')
soup = BeautifulSoup(html_page.content, 'html.parser')

# %%
event_listings = soup.find('div', id="event-listing")
entries = event_listings.findAll('li')
titles = []
venues = []
dates = []
attendees = []
for entry in entries:
    event=entry.find('h1',class_='event-title')
    if event != None:
        event_info = event.text.split('at')
        title = event_info[0].strip()
        titles.append(title)
        venue = event_info[1].strip()
        venues.append(venue)
    date = entry.find('time')
    if date != None:
        date = date.text.split('T')[0]
        dates.append(date)
    attend = entry.find('p',class_='attending')
    if attend != None:
        attend = int(attend.text.split()[0])
        attendees.append(attend)
df = pd.DataFrame([titles,venues,dates,attendees]).transpose()
df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
df
# Out:
#                                            Event_Name  \
# 0                                            ReSolute
# 1   Virtual Thursday: Planetarium with Mr. Curtain...
# 2                                 Joe Wong + Nite Cre
# 3                                Virtual Thursday: Wh
# 4       Virtual Friday: DJ Voices and Zenker Brothers
# 5        [CANCELED] Cristoph - Made Event & Gray Area
# 6                              [POSTPONED] Bicep Live
# 7   Zero presents... Carte Blanche Rooftop Party O...
# 8           Teksupport: Mind Against (All Night Long)
# 9           Never Fake It: Seth Magoon & Mike Guimond
# 10                                          Virtual S
# 11    Virtual Mister Sunday: Eamon Harkin and Acemoma
#
#                                              Venue  Event_Date  \
# 0                                   TBA - New York  2020-05-28
# 1                                         Nowadays  2020-05-28
# 2                                             ures  2020-05-28
# 3                                    is Mutual Aid  2020-05-28
# 4                                         Nowadays  2020-05-29
# 5                                          Quantum  2020-05-29
# 6                                 Knockdown Center  2020-05-30
# 7                                            The W  2020-05-30
# 8                                     99 Scott Ave  2020-05-30
# 9                                          Le Bain  2020-05-30
# 10  urday: Large Marge Power Hour and Noncompliant  2020-05-30
# 11                                        Nowadays  2020-05-31
#
#    Number_of_Attendees
# 0                    6
# 1                    2
# 2                    1
# 3                    1
# 4                    1
# 5                   20
# 6                  101
# 7                    8
# 8                   22
# 9                    4
# 10                   1
# 11                   2

# %%
def scrape_events(events_page_url):
    html_page = requests.get(events_page_url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    event_listings = soup.find('div', id="event-listing")
    entries = event_listings.findAll('li')
    titles = []
    venues = []
    dates = []
    attendees = []
    for entry in entries:
        event=entry.find('h1',class_='event-title')
        if event != None:
            event_info = event.text.split('at')
            title = event_info[0].strip()
            titles.append(title)
            venue = event_info[1].strip()
            venues.append(venue)
        date = entry.find('time')
        if date != None:
            date = date.text.split('T')[0]
            dates.append(date)
        attend = entry.find('p',class_='attending')
        if attend != None:
            attend = int(attend.text.split()[0])
            attendees.append(attend)
    df = pd.DataFrame([titles,venues,dates,attendees]).transpose()
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return(df)

# %%
scrape_events('https://www.residentadvisor.net/events/us/florida')
# Out:
#                                    Event_Name               Venue  Event_Date  \
# 0  (Cancelled) Steve Bug by Link Miami Rebels        Floyd, Miami  2020-05-29
# 1                                     Un_mute  TBA - Miami, Miami  2020-05-29
# 2                                      Zendid  TBA - Miami, Miami  2020-05-30
#
#   Number_of_Attendees
# 0                   2
# 1                   1
# 2                   2

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
html_page = requests.get('https://www.residentadvisor.net/events/us/newyork')
soup = BeautifulSoup(html_page.content, 'html.parser')
next_page = soup.find('li', id="liNext").find('a')
next_page_ext ='/week'+(next_page.get('href','missing').split('/week')[-1])
next_page_url = url + next_page_ext

# %%
def next_page(url):
    html_page = requests.get(url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    split_url = url.split('/week')[0]
    next_page = soup.find('li', id="liNext").find('a')
    next_page_ext ='/week'+(next_page.get('href','missing').split('/week')[-1])
    url = split_url + next_page_ext
    return url

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
list_dfs = []
total_rows = 0
url = "https://www.residentadvisor.net/events/us/newyork"
while total_rows <= 100:
    print(url)
    df = scrape_events(url)
    list_dfs.append(df)
    total_rows += len(df)
    url = next_page(url)
    time.sleep(.2)
df = pd.concat(list_dfs)
df = df.iloc[:100]
print(len(df))
df.sort_values(by=['Number_of_Attendees','Event_Date'],ascending=False)
# Out:
# https://www.residentadvisor.net/events/us/newyork
# https://www.residentadvisor.net/events/us/newyork/week/2020-06-01
# https://www.residentadvisor.net/events/us/newyork/week/2020-06-08
# https://www.residentadvisor.net/events/us/newyork/week/2020-06-15
# https://www.residentadvisor.net/events/us/newyork/week/2020-06-22
# https://www.residentadvisor.net/events/us/newyork/week/2020-06-29
# https://www.residentadvisor.net/events/us/newyork/week/2020-07-06
# https://www.residentadvisor.net/events/us/newyork/week/2020-07-13
# https://www.residentadvisor.net/events/us/newyork/week/2020-07-20
# https://www.residentadvisor.net/events/us/newyork/week/2020-07-27
# https://www.residentadvisor.net/events/us/newyork/week/2020-08-03
# https://www.residentadvisor.net/events/us/newyork/week/2020-08-10
# https://www.residentadvisor.net/events/us/newyork/week/2020-08-17
# https://www.residentadvisor.net/events/us/newyork/week/2020-08-24
# https://www.residentadvisor.net/events/us/newyork/week/2020-08-31
# https://www.residentadvisor.net/events/us/newyork/week/2020-09-07
# https://www.residentadvisor.net/events/us/newyork/week/2020-09-14
# https://www.residentadvisor.net/events/us/newyork/week/2020-09-21
# https://www.residentadvisor.net/events/us/newyork/week/2020-09-28
# https://www.residentadvisor.net/events/us/newyork/week/2020-10-05
# https://www.residentadvisor.net/events/us/newyork/week/2020-10-12
# 100
#                                            Event_Name  \
# 6   [POSTPONED] All Day I Dream Summer Season Opening
# 1             October Moonlight Midnight Yacht Cruise
# 0        Can't Stop The Feeling Midnight Yacht Cruise
# 4   Lane 8 - Brightest Lights Tour (Sunday) - resc...
# 0                              Monolink - rescheduled
# ..                                                ...
# 1   NYC July 4th Weekend Hip Hop vs Reggae® Yacht ...
# 2   NYC Independence Day Weekend Yacht Party Cruis...
# 4                                     718 Sessions Bo
# 3                       [CANCELLED] Wrecked & Carry N
# 9          Don't Stop The Music Midnight Yacht Cruise
#
#                          Venue  Event_Date Number_of_Attendees
# 6              Brooklyn Mirage  2020-06-07                 437
# 1          Harbor Lights Yacht  2020-10-10                 415
# 0          Harbor Lights Yacht  2020-07-24                 219
# 4              Brooklyn Mirage  2020-08-16                 137
# 0   Kings Hall - Avant Gardner  2020-09-30                 122
# ..                         ...         ...                 ...
# 1               Skyport Marina  2020-07-03                None
# 2               Skyport Marina  2020-07-03                None
# 4                   Party 2020  2020-06-28                None
# 3               ion Pride 2020  2020-06-27                None
# 9          Harbor Lights Yacht  2020-06-13                None
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully developed a pipeline to scrape a website for concert event information!
